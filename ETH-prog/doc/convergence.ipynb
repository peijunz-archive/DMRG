# %%
from fractions import Fraction
A=arange(10)

# %%
s=slice(-2, None, -1)

# %%
p=arange(4)
shuffle(p)

# %%
p
# Out:
# array([2, 3, 1, 0])

# %% [markdown]
# + Huge spin, merge sites

# %% [markdown]
# + Final Variance
# + Record energy, and distribution
# + Individual. Typical sample
# + Use average $\beta$? Check $E$ is 0 on average
# + Done. local var

# %%
import ETH.optimize_layers as ol
from DMRG.Ising import Hamilton_TL
from ETH import Rho, Gibbs
import analyse as al
from importlib import reload
reload(ol);

# %%
info = Hamilton_TL(6)

# %%
H = info['H']

# %%
rho = Rho.rho_prod_even(6, 3, rs=np.random)

# %%
r, v2 = ol.minimize_local(H, rho, D=2, L=6, n=300, rel=1e-8)
# Out:
# Exit at 65

# %%
r, v4 = ol.minimize_local(H, rho, D=4, L=6, n=1000, rel=1e-8)
# Out:
# Exit at 999

# %%
r, v6 = ol.minimize_local(H, rho, D=6, L=6, n=1000, rel=1e-8)
# Out:
# Exit at 999

# %%
plot(v2[:300], label='2');
plot(v4[:300], label='4');
plot(v6[:300], label='6');
xlabel('Iteration')
title('Variance')
grid();
legend();

# %%
plot(v2[:300]-v2[-1], label='2');
plot(v4[:300]-v4[-1], label='4');
plot(v6[:300]-v6[-1], label='6');
xlabel('Iteration')
title('Difference compared to final optimal variance')
grid();
legend();

# %%
plot(log10(-diff(v2)), label="D=2")
plot(log10(-diff(v4)), label="D=4")
plot(log10(-diff(v6)), label="D=6")
xlabel('Iteration')
grid();
title('log of first order derivative of variance')
legend();

# %%
imshow(al.diff_gibbs(r, H));

# %%
imshow(al.diff_gibbs(r, H));

# %%
plot(log(-diff(v)), ',');

# %%
imshow(al.diff_gibbs(r, H));

# %%
#r2, v2 = r, v
plot(log10(-diff(v2)), '.');
title("D=2")
grid();

# %%
#r3, v3 = r, v
plot(log10(-diff(v3)), ',');
title("D=3")
grid();

# %%
#r4, v4 = r, v
plot(log10(-diff(v4)), ',');
title("D=4")
grid();

# %%
r6, v6 = r, v
plot(log10(-diff(v6)), ',');
title("D=6")
grid();

# %%
r5, v5 = r, v
plot(log10(-diff(v5)), ',');
title("D=5")
grid();

# %%
#r5, v5 = r, v
plot(log10(-diff(v5)), ',');
title("D=5")
grid();

# %%
imshow(al.diff_gibbs(r6, H))
