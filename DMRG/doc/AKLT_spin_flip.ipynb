# %%
import DMRG.AKLT as ak
from DMRG import spin

# %%
from importlib import reload
reload(ak);

# %%
N=21
s = ak.AKLT_State(N)
s.update_single(spin.P(1), (N-1)//2)
s.canon()
M=ak.Z(s)

# %%
plot(M)

# %%
N=ak.Ztj(s, arange(15)+1, 60)
M=vstack((M, N))

# %%
c=matshow(M)
colorbar(c);
