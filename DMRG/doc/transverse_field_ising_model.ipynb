# %% [markdown]
# # Transverse field Ising model

# %%
# %pylab
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib

# %%
from DMRG import Ising

# %% [markdown]
# # Eigenvalues of Hamiltonian

# %%
help(Ising.Hamilton_trans)
# Out:
# Help on function Hamilton_trans in module DMRG.Ising:
#
# Hamilton_trans(n, g=0, J=1)
#     Hamiltonian for Transverse field Ising Model
#
#     :math:`H=-\sum_i J_i Z_i Z_{i+1} - \sum_i g_i X_i`
#
#     Args
#     ----
#     J: np.ndarray
#         Nearest Coupling Strength
#     g: np.ndarray
#         Transverse field strength
#
#     Returns
#     ---
#         dict:
#             + 'H' is actual Hamiltonian
#             + 'H_template' is the Hamiltonian string
#             + Input parameters are also in the dict

# %%
A=Ising.Hamilton_trans(9, 0.4)['H']
v, w = eigh(A)

# %%
plot(v)
