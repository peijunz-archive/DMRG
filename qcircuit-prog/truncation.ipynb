# %%
ls *.npy
# Out:
# test.npy  untruncated2-dk0.3.npy  untruncated2.npy

# %%
l = load('untruncated2.npy')
cax = imshow(l, aspect=4, vmax=None);
xlabel('sites')
ylabel('time units')
title('Expectation of photon number at each site')
colorbar(cax);
savefig('wavepack.pdf')

# %%
l = load('untruncated2.npy')
cax = imshow(l, vmin=0);
xlabel('sites')
ylabel('time units')
title('Expectation of photon number at each site')
colorbar(cax, orientation='horizontal');
savefig('wavepack.pdf')

# %%
l = log10(load('truncated2.npy').clip(1e-5))
cax = matshow(l, aspect=3);
xlabel('sites')
ylabel('time units')
colorbar(cax);
