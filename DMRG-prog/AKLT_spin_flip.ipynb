# %%
import AKLT as ak

# %%
from importlib import reload
reload(AKLT);

# %%
N=41
s = ak.AKLT_State(N)
s.update_single(spin.P(1), (N-1)//2)
s.canon()
M=ak.Z(s)

# %%
N=ak.Ztj(s, arange(100)+1, 30)
M=vstack((M, N))
save('flip.npy', M)

# %%
M=load('flip.npy')
c=matshow(M)
colorbar(c);
savefig('cmap.pdf')

# %%
plot(M[0])

# %%
plot([0.86275337194630097, 0.73637262177415941, 0.64862712269772815, 0.53505528741109731, 0.46183040806253806, 0.4519930375108186, 0.44444141628139139, 0.40847095924454141, 0.37715660364082904, 0.34650912836909586, 0.33115650059413926, 0.3352931425404273, 0.31786763342691815, 0.29745043984752695, 0.29471138588380258, 0.30450305018154084, 0.32196720233981596, 0.31006839310217099, 0.24833461323940201, 0.13158873356617481, 0.066914405403437072, 0.21285179508504662, 0.35993885079380677, 0.46969451329779471, 0.53809559018361242, 0.55511128590916248, 0.52445169378655265, 0.47567800186881787, 0.41608200816906077, 0.36628822010543555, 0.3491199450453587, 0.32945151440661863, 0.29009691565695345, 0.24547365711226177, 0.2047049732987451, 0.17444592688688132, 0.15542409010926528, 0.15302970576621031, 0.16207510339686748, 0.16475450305463382, 0.14456343251775688, 0.092305570718802382]
)
