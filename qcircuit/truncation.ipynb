# %%
l = log10(load('untruncated.npy').clip(1e-8))
cax = matshow(l, aspect=3);
xlabel('sites')
ylabel('time units')
colorbar(cax);

# %%
l = log10(load('truncated.npy').clip(1e-5))
cax = matshow(l, aspect=3);
xlabel('sites')
ylabel('time units')
colorbar(cax);

# %%
l = log10(load('truncated2.npy').clip(1e-5))
cax = matshow(l, aspect=3);
xlabel('sites')
ylabel('time units')
colorbar(cax);
